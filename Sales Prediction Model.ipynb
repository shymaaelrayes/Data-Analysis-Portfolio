# %% [markdown]
# ## Marketing Analysis for vaious Advertising Channels

# %% [markdown]
# ## Sales Predication Model using Maching Learning linear Regression

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

adv_data = pd.read_excel('advertising.xlsx')
columns = ['TV', 'Radio', 'Newspaper']
for i in columns:
    plt.figure()
    sns.scatterplot(data = adv_data, x=adv_data[i], y= adv_data['Sales'])
X = adv_data.iloc[:,1:4]
Y = adv_data['Sales']  
x_train, x_test, y_train, y_test = train_test_split(X,Y)
linear_model = LinearRegression()
linear_model.fit(x_train, y_train)
y_predict = linear_model.predict(x_test)

# %%
adv_data = pd.read_excel('advertising.xlsx')

# %%
adv_data.head()
# Out:
#         Date     TV  Radio  Newspaper  Sales
# 0 2015-01-01  230.1   37.8       69.2   22.1
# 1 2015-01-08   44.5   39.3       45.1   10.4
# 2 2015-01-15   17.2   45.9       69.3    9.3
# 3 2015-01-22  151.5   41.3       58.5   18.5
# 4 2015-01-29  180.8   10.8       58.4   12.9

# %%
columns = ['TV', 'Radio', 'Newspaper']
for i in columns:
    plt.figure()
    sns.scatterplot(data = adv_data, x=adv_data[i], y= adv_data['Sales'])

# %%
X = adv_data.iloc[:,1:4]
Y = adv_data['Sales']

# %%
x_train, x_test, y_train, y_test = train_test_split(X,Y)

# %%
linear_model = LinearRegression()

# %%
linear_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_predict = linear_model.predict(x_test)

# %%
coefficient = linear_model.coef_
coefficient
# Out:
# array([ 0.04681137,  0.18513762, -0.00022082])

# %%
intercept = linear_model.intercept_
intercept
# Out:
# 2.8523089104792483

# %%
x_train
# Out:
#         TV  Radio  Newspaper
# 85   193.2   18.4       65.7
# 143  104.6    5.7       34.4
# 55   198.9   49.4       60.0
# 165  234.5    3.4       84.8
# 114   78.2   46.8       34.5
# ..     ...    ...        ...
# 35   290.7    4.1        8.5
# 82    75.3   20.3       32.5
# 7    120.2   19.6       11.6
# 139  184.9   43.9        1.7
# 23   228.3   16.9       26.2
#
# [150 rows x 3 columns]

# %%
y_train
# Out:
# 85     15.2
# 143    10.4
# 55     23.7
# 165    11.9
# 114    14.6
#        ...
# 35     12.8
# 82     11.3
# 7      13.2
# 139    20.7
# 23     15.5
# Name: Sales, Length: 150, dtype: float64

# %%
sns.regplot(x=y_test, y=y_predict, ci=None, color="b")
# Out:
# <AxesSubplot:xlabel='Sales'>

# %%
linear_model.predict(np.array([[150,40,50]]))
# Out:
# array([17.26847758])

# %%
linear_model.score(x_test, y_test)
# Out:
# 0.8567362976706147
